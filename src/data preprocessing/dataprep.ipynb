# %%
import pandas as pd
import numpy as np 
import csv
import os 
from spatialmt.config import Paths, Dirs, setup_output_dirs, validate_raw_inputs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 5
#       3 import csv
#       4 import os
# ----> 5 from spatialmt.config import Paths, Dirs, setup_output_dirs, validate_raw_inputs
#
# ModuleNotFoundError: No module named 'spatialmt'

# %%
setup_output_dirs()
validate_raw_inputs()

# %%
tpm_data = pd.read_csv(Paths.Original_TPM_data)
print(f"Loaded TPM data: {tpm_data.shape}")
